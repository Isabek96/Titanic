# %% [markdown]
# # <center>ISsoft ML Meetups

# %% [markdown]
# ## <center>"Машинное обучение: погружение в Kaggle на борту Титаника" (часть первая)
# ![Titanic_intro.png](data:image/png;base64,...)

# %% [markdown]
# #### Что это такое?
#
# - Серия онлайн митапов, посвящённых машинному обучению, соревнованиям с Kaggle, интересным задачам и т.д.

# %% [markdown]
# #### Зачем?
#
# - Помочь найти стартовую точку тем, кто хотел бы начать заниматься ML/Data Science. Дать для этого необходимый набор инструментов, задач; показать, как они решаются.
#
#
# - Показать, что машинное обучение - это не страшно и сложно, а (не)сложно и интересно. Cоздавать и развивать ML-культуру внутри компании.

# %% [markdown]
# #### Для кого?
#
# - Для всех желающих. Особенно подойдёт тем, кто хотел бы начать делать что-то в ML/DS, но не знает, с чего и как можно было бы начать. Знание матанализа, линейной алгебры, теории вероятностей, статистики и т.д. не обязательно, если будет желание - ссылки на материалы помогут покрыть пробелы.

# %% [markdown]
# #### Это НЕ очередные курсы по машинному обучению
#
# Одна из целей митапов - помочь "войти" в ML. Мы будем подбирать интересные задачи, стараться рассказать про них доступным языком, давать базовые решения. *Подробное* изучение теории - на вас. Наша задача состоит в том, чтобы дать базовый минимум и набор инструментов => помочь *подступиться* к той или иной задаче.
#
# В конце всегда будут полезные ссылки на релевантные материалы, статьи, курсы и прочее - для самостоятельного и более углублённого изучения.
#
# Поехали!

# %% [markdown]
# ### Что такое машинное обучение и зачем оно нужно?

# %% [markdown]
# ![2.png](data:image/png;base64,...)

# %% [markdown]
# ###  Искусственный Интеллект VS Машинное Обучение VS Нейросети

# %% [markdown]
# ![3.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### Карта мира машинного обучения

# %% [markdown]
# ![4.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![5.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Что такое Kaggle?

# %% [markdown]
# ![6.png](data:image/png;base64,...)

# %% [markdown]
# Kaggle.com - это платформа для соревнований по машинному обучению. Соревнования проводятся в следующем формате: есть некоторая задача, для решения которой нужно подобрать\придумать и обучить ML-модель на *предоставленных* для этого данных. Качество модели оценивается по некоторой *метрике* (Accuracy, Precision, Recall, AUC-ROC и т.д.), есть лидерборд со списком участников и их текущим результатом. Задачи встречаются разные: работа с табличными данными, компьютерное зрение, обработка естественного языка и т.д. С недавних пор появился раздел с соревнованиями по Reinforcement Learning (Обучение с подкреплением).
#
# На платформе можно как минимум тренировать свои навыки в машинном обучении и анализе данных, как максимум - выигрывать деньги.
#
# Недавно было соревнование по распознаванию дипфейк-роликов, бюджет которого был 1 млн. долларов (на каждое из первых 5 мест по 200.000$)

# %% [markdown]
# #### Плюсы:
#
# - Не нужно самому собирать данные. Их можно просто скачать и тут же приступать к работе
#
#
# - Много соревнований на различные разделы машинного обучения, большинство задач пришли из реального мира. Постоянно встречаются задачи, решив которые лучше остальных (попав в топ 5 private-лидерборда) можно выиграть денежные призы.
#
#
# - Благодаря вышеперечисленным пунктам, Kaggle идеально подходит для изучения ML и каких-то первых шагов в этом направлении.

# %% [markdown]
# #### Минусы
#
# - Благодаря тому, что данные лежат под рукой, соревнования являются скорее исследованиями, нежели какими-то реальными ML-проектами. Минусом это может быть потому, что в реальности поиску и обработке данных для какой-то ML-задачи может уделяться огромный кусок времени, т.е. в этом смысле соревнования оторваны от реальности.

# %% [markdown]
# # <center>Titanic : Machine Learning from Disaster - описание задачи

# %% [markdown]
# ![7.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Даны две таблицы (выборки) - тренировочная и тестовая -  с данными о пассажирах Титаника в формате .csv. Каждая строка = признаковое описание одного из пассажиров. Для тестовой выборки нужно предсказать, выжил ли пассажир - целевая переменная (колонка, target) "Survived".
#
#
#
# - **train.csv** - данные для обучения модели, содержат колонку "Survived"
#
#
# - **test.csv** - данные для которых нужно сделать предсказание, колонки с ответом не содержат

# %% [markdown]
# ![8.png](data:image/png;base64,...)

# %% [markdown]
# Задача является задачей бинарной классификации, так как для каждого из наблюдений (т.е. для пассажира) нам нужно предсказать, выжил он или нет (для целевой переменной "Survived" существует только два значения: 1 и 0 соответственно).
#
#
# Задача является задачей обучения с учителем (supervised learning) : для тренировочной выборки у нас есть "ответы".

# %% [markdown]
# **Признаки (колонки, переменные, атрибуты) датасета:**
#
#
# - **Pclass** - класс, в котором плыл пассажир, passenger class
#
#
# - **SibSp** - количество братьев-сестёр/супругов на борту, sibling/spouse
#
#
# - **Parch** - количество детей/родителей пассажира на борту, parent/children
#
#
# - **Cabin** - номер каюты
#
# и т.д.

# %% [markdown]
# **Ссылка на соревнование на Kaggle: https://www.kaggle.com/c/titanic/overview**

# %% [markdown]
# ### Что будем использовать
#
# ![9.png](data:image/png;base64,...)
#
#
# Для различных целей будем использовать различные python-библиотеки, заточенные под ML и работу с данными:
# - **Pandas** - загрузка данных из различных spreadsheet-форматов (.csv, .tsv, .txt и тд.) в DataFrame. Даёт возможность удобно и просто работать с данными в табличном формате, преобразовывать их (в том числе с помощью SQL-подобных операций), создавать кросс-таблицы и тд.
#
# - **NumPy** - математические функции, многомерные матрицы, векторы.
#
# - **Scikit-learn (sklearn)** - различные модели "классического" машинного обучения (нет возможности послойно создавать свои нейросети, хотя есть несколько готовых нейросетевых моделей). Кроме самих моделей содержит полезные утилитные функции для подбора гиперпараметров модели, оценки качества модели, разбития данных и т.д.
#
# - **Matplotlib, Seaborn** - визуализация данных (построение различных графиков)
#
#
# - И другие
#
# Скачать все необходимые библиотеки, python, jupyter notebook (то, что мы используем в качестве IDE) можно вместе с пакетом **Anaconda**
#
# **Ссылка:** https://www.anaconda.com/products/individual

# %% [markdown]
# ## Этап 1. Работа с данными (Exploratory data analysis)

# %%
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns

# %%
#Путь к данным
#ВАЖНО! При локальной работе с данными можете поменять это на местоположение данных на вашей машине

PATH_TO_TRAIN = '<dataset/ML_Weekly/1/train.csv>'
PATH_TO_TEST = '<dataset/ML_Weekly/1/test.csv>'

# %%
#Загрузка данных

train = pd.read_csv(PATH_TO_TRAIN, index_col='PassengerId') #обучающая выборка
test = pd.read_csv(PATH_TO_TEST, index_col='PassengerId')   #тестовая выборка (для неё будем предсказывать)

# %%
train
# Out:
#              Survived  Pclass  ... Cabin Embarked
# PassengerId                    ...
# 1                   0       3  ...   NaN        S
# 2                   1       1  ...   C85        C
# 3                   1       3  ...   NaN        S
# 4                   1       1  ...  C123        S
# 5                   0       3  ...   NaN        S
# ...               ...     ...  ...   ...      ...
# 887                 0       2  ...   NaN        S
# 888                 1       1  ...   B42        S
# 889                 0       3  ...   NaN        S
# 890                 1       1  ...  C148        C
# 891                 0       3  ...   NaN        Q
#
# [891 rows x 11 columns]

# %%
train.head(5)
# Out:
#              Survived  Pclass  ... Cabin Embarked
# PassengerId                    ...
# 1                   0       3  ...   NaN        S
# 2                   1       1  ...   C85        C
# 3                   1       3  ...   NaN        S
# 4                   1       1  ...  C123        S
# 5                   0       3  ...   NaN        S
#
# [5 rows x 11 columns]

# %%
train.tail()
# Out:
#              Survived  Pclass  ... Cabin Embarked
# PassengerId                    ...
# 887                 0       2  ...   NaN        S
# 888                 1       1  ...   B42        S
# 889                 0       3  ...   NaN        S
# 890                 1       1  ...  C148        C
# 891                 0       3  ...   NaN        Q
#
# [5 rows x 11 columns]

# %%
#так можно делать подвыборки из данных

train[(train['Age'] == 14)]
# Out:
#              Survived  Pclass  ...    Cabin Embarked
# PassengerId                    ...
# 10                  1       2  ...      NaN        C
# 15                  0       3  ...      NaN        S
# 40                  1       3  ...      NaN        C
# 436                 1       1  ...  B96 B98        S
# 684                 0       3  ...      NaN        S
# 687                 0       3  ...      NaN        S
#
# [6 rows x 11 columns]

# %%
#так можно делать подвыборки из данных

train[(train['Sex'] == 'male') & (train['Embarked'] == 'S')]
# Out:
#              Survived  Pclass  ... Cabin Embarked
# PassengerId                    ...
# 1                   0       3  ...   NaN        S
# 5                   0       3  ...   NaN        S
# 7                   0       1  ...   E46        S
# 8                   0       3  ...   NaN        S
# 13                  0       3  ...   NaN        S
# ...               ...     ...  ...   ...      ...
# 879                 0       3  ...   NaN        S
# 882                 0       3  ...   NaN        S
# 884                 0       2  ...   NaN        S
# 885                 0       3  ...   NaN        S
# 887                 0       2  ...   NaN        S
#
# [441 rows x 11 columns]

# %%
#аналогичный способ выбрать те же строчки, при помощи метода quiery

train.query("Sex == 'male' & Embarked == 'S'")
# Out:
#              Survived  Pclass  ... Cabin Embarked
# PassengerId                    ...
# 1                   0       3  ...   NaN        S
# 5                   0       3  ...   NaN        S
# 7                   0       1  ...   E46        S
# 8                   0       3  ...   NaN        S
# 13                  0       3  ...   NaN        S
# ...               ...     ...  ...   ...      ...
# 879                 0       3  ...   NaN        S
# 882                 0       3  ...   NaN        S
# 884                 0       2  ...   NaN        S
# 885                 0       3  ...   NaN        S
# 887                 0       2  ...   NaN        S
#
# [441 rows x 11 columns]

# %%
#так можно посмотреть на информацию о колонках: типы данных, количество пропущенных значений и т.д

train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 418 entries, 892 to 1309
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pclass    418 non-null    int64
#  1   Name      418 non-null    object
#  2   Sex       418 non-null    object
#  3   Age       332 non-null    float64
#  4   SibSp     418 non-null    int64
#  5   Parch     418 non-null    int64
#  6   Ticket    418 non-null    object
#  7   Fare      417 non-null    float64
#  8   Cabin     91 non-null     object
#  9   Embarked  418 non-null    object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 35.9+ KB

# %%
#удаление ненужных колонок

useless_columns = ['Name', 'Ticket', 'Cabin']

train_clean = train.drop(columns=useless_columns)
test_clean = test.drop(columns=useless_columns)

# %% [markdown]
# ### Заполнение пропусков в данных

# %%
#imputing - заполнение пропущенных данных

def impute_data(df):
    
    df_copy = df.copy() #копируем, чтобы не изменять оригинал
    
    #заполняем пропущенные значения для категориальных переменных самым частым значением в колонке
    categorial_vars = list(df_copy.select_dtypes(include=['object']).columns.values)
    for col in categorial_vars:
        
        if (df_copy[col].isnull().values.any()):
            df_copy[col].fillna(df_copy[col].mode()[0], inplace=True)
    
    
    
    #заполняем пропущенные значения для количественных переменных медианой по столбцу
    numerical_vars = list(df_copy.select_dtypes(include=['int64', 'float64']).columns.values)
    for col in numerical_vars:        
        if (df_copy[col].isnull().values.any()):
            df_copy[col].fillna(df_copy[col].median(), inplace=True)

            
    return df_copy

# %%
train_full = impute_data(train_clean)
test_full = impute_data(test_clean)

# %%
#Проверим данные после заполнения

train_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       891 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Embarked  891 non-null    object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 62.6+ KB

# %%
test_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 418 entries, 892 to 1309
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pclass    418 non-null    int64
#  1   Sex       418 non-null    object
#  2   Age       418 non-null    float64
#  3   SibSp     418 non-null    int64
#  4   Parch     418 non-null    int64
#  5   Fare      418 non-null    float64
#  6   Embarked  418 non-null    object
# dtypes: float64(2), int64(3), object(2)
# memory usage: 26.1+ KB

# %% [markdown]
# ### Визуализация данных
#
# В этом подразделе будет показано, как при помощи всего лишь одного графика можно очень хорошо изучить данные

# %%
#мужчины умирают гораздо чаще

sns.catplot('Sex', data=train_full, hue='Survived', kind='count');

# %%
#бедные тоже

sns.catplot('Pclass', data=train_full, hue='Survived', kind='count');

# %%
#При этом, бедных было больше всего

sns.catplot('Pclass', data=train_full, kind='count');

# %%
#Бедных мужчин было больше всего

sns.catplot('Pclass', data=train_full, hue='Sex', kind='count');

# %%
#И выживших среди них меньше всего

sns.catplot(x="Sex", y="Survived", col="Pclass", data=train_full, kind="bar");

# %%
#от количества членов семьи также зависит выживаемость
#здесь это количество супругов + родственников пассажира (признак SibSp)

sns.catplot('SibSp', data=train_full, hue='Survived', kind='count');

# %%
#от количества членов семьи также зависит выживаемость
#здесь это количество детей + родителей пассажира (признак Parch)

sns.catplot('Parch', data=train_full, hue='Survived', kind='count');

# %% [markdown]
# ### Feature Engineering
#
# Мы заметили, что количество детей и родственников влияет на выживаемость. Объединим это в новый признак *Family_size*

# %%
#создать новую колонку-признак в DataFrame очень просто:

train_full['Family_size'] = train_full['Parch'] + train_full['SibSp']
test_full['Family_size'] = test_full['Parch'] + test_full['SibSp']

train_full.head()
# Out:
#              Survived  Pclass     Sex  ...     Fare  Embarked  Family_size
# PassengerId                            ...
# 1                   0       3    male  ...   7.2500         S            1
# 2                   1       1  female  ...  71.2833         C            1
# 3                   1       3  female  ...   7.9250         S            0
# 4                   1       1  female  ...  53.1000         S            1
# 5                   0       3    male  ...   8.0500         S            0
#
# [5 rows x 9 columns]

# %%
#Новый признак помогает лучше отделить случаи, в которых люди выживали

sns.catplot('Family_size', data=train_full, hue='Survived', kind='count');

# %%
#признак, в большей степени, касается женщин

sns.catplot('Family_size', data=train_full, hue='Sex', kind='count');

# %% [markdown]
# ### Сохранение данных

# %%
#сохраним данные в файл, чтобы не потерять изменения

train_full.to_csv('train_imputed.csv')
test_full.to_csv('test_imputed.csv')

# %% [markdown]
# ### Пример очень простой baseline-модели (решающий пень, decision stump)

# %%
#таким образом можно получить булев вектор, содержащий условие

(test_full['Sex'] == 'male')
# Out:
# PassengerId
# 892      True
# 893     False
# 894      True
# 895      True
# 896     False
#         ...
# 1305     True
# 1306    False
# 1307     True
# 1308     True
# 1309     True
# Name: Sex, Length: 418, dtype: bool

# %%
(test_full['Sex'] == 'male') & (test_full['Pclass'] == 3)
# Out:
# PassengerId
# 892      True
# 893     False
# 894     False
# 895      True
# 896     False
#         ...
# 1305     True
# 1306    False
# 1307     True
# 1308     True
# 1309     True
# Length: 418, dtype: bool

# %%
#Выбираем всех мужчин, которые были в 3-ем (бедном) классе и говорим, что они не выжили


simple_pred = (~((test_full['Sex'] == 'male') & (test_full['Pclass'] == 3))).astype(int).values

# %% [markdown]
# ![10.png](data:image/png;base64,...)

# %% [markdown]
# ### Оформление результата

# %%
#функция для составления submission-файла соревнования

def make_prediction_file(prediction, test_data, name):
    
    result = pd.DataFrame({'PassengerId': test_data.reset_index()['PassengerId'], "Survived": prediction})  
    result.to_csv(name, index=False)

# %%
make_prediction_file(simple_pred, test, 'titanic_simple_baseline.csv')

# %% [markdown]
# ![11.png](data:image/png;base64,...)

# %% [markdown]
# ### Итог:
#
# Для того, чтобы подступиться к задаче, нужно:
#
# - Найти данные. Без них никак. Совсем.
# - Загрузить их. Посмотреть на них. Пристально.
# - Проверить, есть ли в данных пропуски. Заполнить (например, медианой для числовых и модой для качественных). Неинформативные или почти пустые колонки можно выбросить.
# - Творческая часть - визуализировать данные, попытаться найти в них какие-то интересные закономерности.
# - Творческая часть - придумать какой-нибудь новый признак (а лучше несколько). Как было показано, визуализация может с этим помочь.
# - На основании такого изучения данных сделать какие-то начальные выводы, наброски решения.
#
#
# То, что мы получили в самом конце - решающий пень - является лишь базовой (baseline)-моделью: мы вручную, благодаря визуальному анализу, отобрали признаки, которые помогли с почти 60%-ой точностью определить выживаемость пассажира. В следующей части мы разовьём эту идею и используем уже "настоящий" алгоритм машинного обучения - Decision Tree.

# %% [markdown]
# ### Try to do yourself (optional)
#
# На этом этапе просто потренируйтесь использовать библиотеки для EDA-анализа данных: pandas и seaborn (matplotlib). Ниже будут предложены идеи, чтобы получше разобраться в инструментах.

# %% [markdown]
# - Потренируйтесь делать подвыборки из данных: при помощи индексации квадратными скобками, при помощи метода **query**. Для подвыборок посмотрите статистику.
#
#
# - Потренируйтесь объединять датасеты: изучите методы **join** и **concat**. Например, вы можете сделать несколько подвыборок из исходных данных, сохранить их каждый в свой DataFrame, а потом заново их склеить в один большой. После - можете проверить, корректно ли вы это сделали, проверив некоторые атрибуты склеенного DataFrame.
#
#
# - Визуализируйте распределение цены за билет (Fare), возраста пассажиров.
#
#
# - Загрузите оригинальные данные (потому что в них есть колонка с именем). Найдите самое популярное мужское (или женское) имя на корабле. *Посказка*: для того, чтобы применить к датасету (или его колонке\строке) какую-либо функцию, можно воспользоваться методом **apply** из библиотеки Pandas. Может не получиться с первого раза, не расстраивайтесь, если не получится.

# %%
#ваш код здесь

# %% [markdown]
# ### Полезные ссылки
#
# - https://www.kaggle.com/c/titanic - Titanic: Machine Learning from Disaster - ссылка на наше сегодняшнее соревнование, Kaggle. Для участия необходимо создать учётную запись.
#
#
#
# - https://www.anaconda.com/products/individual - Anaconda3 - toolkit, в котором есть все необходимые инструменты для того, чтобы начать заниматься Data Science: Python последней версии, все использованные сегодня библиотеки (и куча других, ориентированных на ML/DS и научные вычисления), Jupyter Notebook и т.д.
#
#
# - https://vas3k.ru/blog/machine_learning/ - простая и интересная вводная статья о машинном обучении, из которой была взята часть картинок.
#
#
# - https://habr.com/ru/company/ods/blog/322626/ - курс Open Data Science - крупнейшего русскоязычного Data Science-сообщества. Бесплатный, в рамках сегодняшней темы можно почитать первых два урока.
